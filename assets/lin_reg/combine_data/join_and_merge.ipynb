# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dash = pd.read_csv("FourtyYardDash.csv")
jump = pd.read_csv("CounterMovementJump.csv")
pull = pd.read_csv("IsometricMidThighPull.csv")
agil = pd.read_csv("ProAgility.csv")

# %%
#check that name is unique and is a primary key

# %%
def is_composite_key(df, cols):
    return df[cols].isna().any().any() == False and \
           df[cols].drop_duplicates().shape[0] == df.shape[0]

is_composite_key(dash, ['name'])
# Out:
# True

# %%
type(jump["name"][0])
# Out:
# str

# %%
combine_df = dash.merge(jump, on= "name", how="outer",suffixes=["_dash","_jump"])
combine_df =
# Out:
#    sex_dash         movement_dash  fourty_yard_dash_total_time_seconds  \
# 0     Women  40 Yard Dash Results                                5.359
# 1       Men  40 Yard Dash Results                                5.330
# 2     Women  40 Yard Dash Results                                5.757
# 3       Men  40 Yard Dash Results                                5.261
# 4     Women  40 Yard Dash Results                                5.753
# ..      ...                   ...                                  ...
# 88      Men  40 Yard Dash Results                                4.893
# 89      Men  40 Yard Dash Results                                5.056
# 90      Men  40 Yard Dash Results                                4.775
# 91      Men  40 Yard Dash Results                                4.210
# 92      Men  40 Yard Dash Results                                5.080
#
#     fourty_yard_dash_avg_time_seconds  delta_total_average_dash  \
# ...
